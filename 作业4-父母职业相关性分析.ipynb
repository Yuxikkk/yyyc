# %%
#任务1:csv格式数据的读写查询
import pandas as pd

# %%
df1=pd.read_csv('类别变量练习数据.csv',encoding='GBK')

# %%
import mytools
# import pandas as pd
# from pyreadstat import pyreadstat

# %%
tau_y = mytools.goodmanKruska_tau_y(df1,'父亲职业重新编码','母亲职业重新编码')
tau_y
# Out:
# 0.8766963011149058

# %%
mytools.相关系数强弱判断(tau_y)
# Out:
# '极强相关'

# %%
df1['父亲职业重新编码'].value_counts()
# Out:
# 父亲职业重新编码
# 公务员     22
# 民企       9
# 个体       9
# 国企       6
# 家庭主妇     3
# 事业单位     2
# 国企·      1
# 民企·      1
# Name: count, dtype: int64

# %%
df1['母亲职业重新编码'].value_counts()
# Out:
# 母亲职业重新编码
# 家庭主妇    15
# 公务员     14
# 事业单位     9
# 民企       6
# 个体       5
# 国企       3
# 上市民企     1
# Name: count, dtype: int64

# %%
mytools.plot_variable_pie(df1,'母亲职业重新编码')

# %%
mytools.plot_variable_pie(df1,'父亲职业重新编码')

# %%
def 制作交叉表(数据表,自变量,因变量):
   自变量数据=数据表[自变量]
   因变量数据=数据表[因变量]
   return pd.crosstab(自变量数据,因变量数据,normalize='columns',margins=True)

# %%
mytools.制作交叉表(df1,'父亲职业重新编码','母亲职业重新编码')
# Out:
# 母亲职业重新编码  上市民企   个体      事业单位       公务员        国企      家庭主妇        民企  \
# 父亲职业重新编码
# 个体         0.0  0.6  0.000000  0.000000  0.000000  0.333333  0.166667
# 事业单位       0.0  0.0  0.222222  0.000000  0.000000  0.000000  0.000000
# 公务员        0.0  0.0  0.666667  0.714286  0.666667  0.066667  0.500000
# 国企         0.0  0.4  0.000000  0.000000  0.000000  0.200000  0.166667
# 国企·        0.0  0.0  0.000000  0.000000  0.333333  0.000000  0.000000
# 家庭主妇       0.0  0.0  0.000000  0.071429  0.000000  0.133333  0.000000
# 民企         1.0  0.0  0.111111  0.142857  0.000000  0.266667  0.166667
# 民企·        0.0  0.0  0.000000  0.071429  0.000000  0.000000  0.000000
#
# 母亲职业重新编码       All
# 父亲职业重新编码
# 个体        0.169811
# 事业单位      0.037736
# 公务员       0.415094
# 国企        0.113208
# 国企·       0.018868
# 家庭主妇      0.056604
# 民企        0.169811
# 民企·       0.018868

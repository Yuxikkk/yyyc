# %%
import pandas as pd
# 读取上传的 Excel 文件
import pandas as pd
file_path_excel = R'国家认同数据清理后.xlsx'
df_excel = pd.read_excel(file_path_excel)
# 创建民族、年级和政治面貌的交互表
cross_tab = pd.crosstab(index=[df_excel['年级'], df_excel['会打多少分']], 
                        columns=df_excel['政治面貌'], 
                        margins=True)  # All 行和列的总和

cross_tab
# Out:
# 政治面貌         1    2   3   4  All
# 年级  会打多少分
# 0   3        4    0   0   0    4
#     4        7    0   0   0    7
#     5        1    0   1   0    2
# 1   1        5    0   1   0    6
#     2        8    0   1   0    9
#     3       25    4   3   3   35
#     4      118    6  13   0  137
#     5       71    2   8   0   81
# 2   1        9    1   0   0   10
#     2       10    1   1   0   12
#     3       34    9  13   1   57
#     4       86    6   8   3  103
#     5       52   10   4   1   67
# 3   1        3    2   2   0    7
#     2        2    1   0   0    3
#     3       20    8   5   1   34
#     4       38   26  12   4   80
#     5       24    7   3   3   37
# 4   1        0    2   0   0    2
#     2        1    0   1   0    2
#     3        8    4   4   0   16
#     4       29    6   4   0   39
#     5       19    8   2   0   29
# All        574  103  86  16  779

# %%
from scipy import stats
# 假设我们关注的是第二年级的学生（假设年级用数字“2”表示）
specific_grade = 2

# 筛选出特定年级的数据
df_specific_grade = df_excel[df_excel['年级'] == specific_grade]

# 创建年级、政治面貌和会打多少分的交互表
cross_tab_specific_grade = pd.crosstab(df_specific_grade['民族'], df_specific_grade['政治面貌'])

# 进行卡方检验
chi2_grade, p_grade, dof_grade, expected_grade = stats.chi2_contingency(cross_tab_specific_grade)

chi2_grade, p_grade, dof_grade, expected_grade[:10]  # 展示期望频次的前10个结果，避免过长的输出
# Out:
# (72.71688752254215,
#  0.0455610581920747,
#  54,
#  array([[9.05140562e+01, 1.27951807e+01, 1.23212851e+01, 2.36947791e+00],
#         [1.15060241e+01, 1.62650602e+00, 1.56626506e+00, 3.01204819e-01],
#         [3.14497992e+01, 4.44578313e+00, 4.28112450e+00, 8.23293173e-01],
#         [1.07389558e+01, 1.51807229e+00, 1.46184739e+00, 2.81124498e-01],
#         [6.90361446e+00, 9.75903614e-01, 9.39759036e-01, 1.80722892e-01],
#         [4.60240964e+00, 6.50602410e-01, 6.26506024e-01, 1.20481928e-01],
#         [1.53413655e+00, 2.16867470e-01, 2.08835341e-01, 4.01606426e-02],
#         [9.20481928e+00, 1.30120482e+00, 1.25301205e+00, 2.40963855e-01],
#         [1.53413655e+00, 2.16867470e-01, 2.08835341e-01, 4.01606426e-02],
#         [7.67068273e-01, 1.08433735e-01, 1.04417671e-01, 2.00803213e-02]]))

# %%
import mytools

# %%
mytools.两个无序类别变量的统计分析(df_excel,'会打多少分','年级')
# Out:
# tau_y系数: 0.0095 极弱相关或无相关
# -  -  ---  ---  --  --
# 1  0    6   10   7   2
# 2  0    9   12   3   2
# 3  4   35   57  34  16
# 4  7  137  103  80  39
# 5  2   81   67  37  29
# -  -  ---  ---  --  --
# 卡方值： 21.14, p值： 0.1731,自由度:16。
# 接受虚无假设

# %%
import pandas as pd
file_path_spss = R'国家认同数据清理后.sav'

# %%
df_spss =pd.read_spss(file_path_spss)
# 创建年级、政治面貌和会打多少分的交互表
cross_tab = pd.crosstab(index=[df_spss['年级'], df_spss['中国传统文化']], 
                        columns=df_spss['政治面貌'], 
                        margins=True, normalize=True)  # All 行和列的总和
cross_tab
# Out:
# 政治面貌                 党员        其他        团员        群众       All
# 年级  中国传统文化
# 大一  古板，跟不上潮流   0.001284  0.000000  0.003851  0.002567  0.007702
#     富有内涵，意义深刻  0.014121  0.002567  0.209243  0.023107  0.249037
#     比较肯定       0.000000  0.001284  0.078306  0.007702  0.087291
# 大三  古板，跟不上潮流   0.001284  0.000000  0.003851  0.002567  0.007702
#     富有内涵，意义深刻  0.042362  0.007702  0.075738  0.015404  0.141207
#     比较肯定       0.012837  0.002567  0.032092  0.010270  0.057766
# 大二  古板，跟不上潮流   0.001284  0.000000  0.002567  0.003851  0.007702
#     富有内涵，意义深刻  0.029525  0.005135  0.170732  0.023107  0.228498
#     比较肯定       0.003851  0.001284  0.071887  0.006418  0.083440
# 大四  古板，跟不上潮流   0.000000  0.000000  0.002567  0.001284  0.003851
#     富有内涵，意义深刻  0.014121  0.000000  0.055199  0.010270  0.079589
#     比较肯定       0.011553  0.000000  0.015404  0.002567  0.029525
# 预科  富有内涵，意义深刻  0.000000  0.000000  0.008986  0.000000  0.008986
#     比较肯定       0.000000  0.000000  0.006418  0.001284  0.007702
# All            0.132221  0.020539  0.736842  0.110398  1.000000

# %%
from scipy import stats
# 假设我们关注的是第二年级的学生（假设年级用数字“2”表示）
specific_grade = '大一'

# 筛选出特定年级的数据
df_specific_grade = df_spss[df_spss['年级'] == specific_grade]

# 创建政治面貌和会打多少分的交互表
cross_tab_specific_grade = pd.crosstab(df_specific_grade['中国传统文化'], df_specific_grade['政治面貌'],margins=True, normalize=True,)

# 进行卡方检验
chi2_grade, p_grade, dof_grade, expected_grade = stats.chi2_contingency(cross_tab_specific_grade)

print(chi2_grade,p_grade)
cross_tab_specific_grade
# Out:
# 0.03886504755673896 0.9999999999999264
# 政治面貌             党员        其他        团员        群众       All
# 中国传统文化
# 古板，跟不上潮流   0.003731  0.000000  0.011194  0.007463  0.022388
# 富有内涵，意义深刻  0.041045  0.007463  0.608209  0.067164  0.723881
# 比较肯定       0.000000  0.003731  0.227612  0.022388  0.253731
# All        0.044776  0.011194  0.847015  0.097015  1.000000

# %%
mytools.两个无序类别变量的统计分析(df_specific_grade,'政治面貌','中国传统文化')
# Out:
# tau_y系数: 0.0135 极弱相关或无相关
# ----  -  ---  --
# 党员  1   11   0
# 其他  0    2   1
# 团员  3  163  61
# 群众  2   18   6
# ----  -  ---  --
# 卡方值： 10.42, p值： 0.1082,自由度:6。
# 接受虚无假设
